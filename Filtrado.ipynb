# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("Milan.csv")
df.head(2)
# Out:
#    Unnamed: 0       scrape_id last_scraped       source  \
# 0           0  20250619031327   2025-06-19  city scrape
# 1           1  20250619031327   2025-06-19  city scrape
#
#                                   name  \
# 0  Loft with garden on Naviglio Grande
# 1  2 rooms apartment in downtown Milan
#
#                                          description  \
# 0  gorgeous loft with garden. Very quiet and comf...
# 1                                                NaN
#
#                                neighborhood_overview  host_id  \
# 0  Neighborhood made by artists, designers, pubs,...  2643876
# 1  The apartment is close to Ticinese going out a...  1442498
#
#                                     host_url host_name  ... last_review  \
# 0  https://www.airbnb.com/users/show/2643876   Barbara  ...  2023-01-01
# 1  https://www.airbnb.com/users/show/1442498     Elena  ...  2024-04-16
#
#   review_scores_rating review_scores_cleanliness review_scores_checkin  \
# 0                 4.22                      4.00                  4.22
# 1                 4.29                      4.43                  4.29
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.56                   4.25                4.22
# 1                        4.64                   4.50                3.93
#
#               license  calculated_host_listings_count  reviews_per_month
# 0  IT015146C2XCMAQN43                               1               0.06
# 1  IT015146C2GRLPV2TY                               1               0.13
#
# [2 rows x 51 columns]

# %%
df1 = df.drop(columns=["Unnamed: 0"])
df1.head(2)
# Out:
#         scrape_id last_scraped       source  \
# 0  20250619031327   2025-06-19  city scrape
# 1  20250619031327   2025-06-19  city scrape
#
#                                   name  \
# 0  Loft with garden on Naviglio Grande
# 1  2 rooms apartment in downtown Milan
#
#                                          description  \
# 0  gorgeous loft with garden. Very quiet and comf...
# 1                                                NaN
#
#                                neighborhood_overview  host_id  \
# 0  Neighborhood made by artists, designers, pubs,...  2643876
# 1  The apartment is close to Ticinese going out a...  1442498
#
#                                     host_url host_name  host_since  ...  \
# 0  https://www.airbnb.com/users/show/2643876   Barbara  2012-06-15  ...
# 1  https://www.airbnb.com/users/show/1442498     Elena  2011-11-25  ...
#
#   last_review review_scores_rating review_scores_cleanliness  \
# 0  2023-01-01                 4.22                      4.00
# 1  2024-04-16                 4.29                      4.43
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  4.22                        4.56                   4.25
# 1                  4.29                        4.64                   4.50
#
#   review_scores_value             license  calculated_host_listings_count  \
# 0                4.22  IT015146C2XCMAQN43                               1
# 1                3.93  IT015146C2GRLPV2TY                               1
#
#   reviews_per_month
# 0              0.06
# 1              0.13
#
# [2 rows x 50 columns]

# %%
#Eliminar un signo de una columna 
df1['price']= df1['price'].str.replace('$','')
df1['price']= df1['price'].str.replace(',','')

# %%
#Conversion de  tipo de datode columna de tipo Object a Float 
df1['price']= df1['price'].astype(float)

# %%
#1. Los host que se hayan registrado antes del 31 de dic del 2022. 
#Filtro por objeto
filtro=df1[df1["host_since"] < "2022-12-31"]

#Los registros de los host que responden “a más tardar en 1 día”
#Filtro por objeto
filtro=df1[(df1["host_response_time"] == "within a day") | (df1["host_response_time"] == "within an hour") | (df1["host_response_time"] == "within a few hours")]

#Que sea casa o apartamento completo o un cuarto privado. 
#Filtro o
filtro=df1[(df1["room_type"] == "Entire home/apt") | (df1["room_type"] == "Private room")]

#Que tengan maximo 2 camas. 
#Filtro por comparacion
filtro=df1[df1["beds"] <=2]

#Que el host este catalogado como superhost.
#Filtro por comparacion
filtro=df1[df1["host_is_superhost"] == "t"]

#Que tenga 1 baño.
#Filtro por comparacion
filtro=df1[df1["bathrooms"] == 1]

#Que el costo sea de $300 a $1000
#Filtro Y
filtro=df1[(df1["price"] >=300) & (df1["price"] <=1000)]

filtro.head(2)
# Out:
#          scrape_id last_scraped       source  \
# 4   20250619031327   2025-06-19  city scrape
# 21  20250619031327   2025-06-19  city scrape
#
#                                         name  \
# 4   Milano Central Luxury - 3 BDR / 7 Guests
# 21    Porta Vigentina Triplex in City Center
#
#                                           description  \
# 4   A stylish and cozy apartment, beautifully furn...
# 21  The apartment is in a beautiful 18C building a...
#
#                                 neighborhood_overview  host_id  \
# 4   The Central Luxury apartment, is located just ...  2718914
# 21                                                NaN   380378
#
#                                      host_url host_name  host_since  ...  \
# 4   https://www.airbnb.com/users/show/2718914    Nicola  2012-06-23  ...
# 21   https://www.airbnb.com/users/show/380378    Andrea  2011-02-07  ...
#
#    last_review review_scores_rating review_scores_cleanliness  \
# 4   2025-05-20                 4.82                      4.90
# 21  2024-04-21                 4.67                      4.89
#
#    review_scores_checkin review_scores_communication review_scores_location  \
# 4                   4.89                        4.89                   4.76
# 21                  5.00                        5.00                   4.89
#
#    review_scores_value             license  calculated_host_listings_count  \
# 4                 4.71  IT015146B4CCMWJAB7                              27
# 21                4.33                 NaN                               1
#
#    reviews_per_month
# 4               0.91
# 21              0.06
#
# [2 rows x 50 columns]

# %%
#Convertir archivo filtrado a CSV
filtro.to_csv("Filtrado.csv")
