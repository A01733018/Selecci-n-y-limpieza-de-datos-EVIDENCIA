# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data = pd.read_csv('Filtrado.csv')
data.head(2)
# Out:
#    Unnamed: 0       scrape_id last_scraped       source  \
# 0           4  20250619031327   2025-06-19  city scrape
# 1          21  20250619031327   2025-06-19  city scrape
#
#                                        name  \
# 0  Milano Central Luxury - 3 BDR / 7 Guests
# 1    Porta Vigentina Triplex in City Center
#
#                                          description  \
# 0  A stylish and cozy apartment, beautifully furn...
# 1  The apartment is in a beautiful 18C building a...
#
#                                neighborhood_overview  host_id  \
# 0  The Central Luxury apartment, is located just ...  2718914
# 1                                                NaN   380378
#
#                                     host_url host_name  ... last_review  \
# 0  https://www.airbnb.com/users/show/2718914    Nicola  ...  2025-05-20
# 1   https://www.airbnb.com/users/show/380378    Andrea  ...  2024-04-21
#
#   review_scores_rating review_scores_cleanliness review_scores_checkin  \
# 0                 4.82                      4.90                  4.89
# 1                 4.67                      4.89                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.89                   4.76                4.71
# 1                        5.00                   4.89                4.33
#
#               license  calculated_host_listings_count  reviews_per_month
# 0  IT015146B4CCMWJAB7                              27               0.91
# 1                 NaN                               1               0.06
#
# [2 rows x 51 columns]

# %%
#Realizamos una copia del dataframe
data1=data.copy()

# %%
data1 = data.drop(columns=["Unnamed: 0"])
data1.head(2)
# Out:
#         scrape_id last_scraped       source  \
# 0  20250619031327   2025-06-19  city scrape
# 1  20250619031327   2025-06-19  city scrape
#
#                                        name  \
# 0  Milano Central Luxury - 3 BDR / 7 Guests
# 1    Porta Vigentina Triplex in City Center
#
#                                          description  \
# 0  A stylish and cozy apartment, beautifully furn...
# 1  The apartment is in a beautiful 18C building a...
#
#                                neighborhood_overview  host_id  \
# 0  The Central Luxury apartment, is located just ...  2718914
# 1                                                NaN   380378
#
#                                     host_url host_name  host_since  ...  \
# 0  https://www.airbnb.com/users/show/2718914    Nicola  2012-06-23  ...
# 1   https://www.airbnb.com/users/show/380378    Andrea  2011-02-07  ...
#
#   last_review review_scores_rating review_scores_cleanliness  \
# 0  2025-05-20                 4.82                      4.90
# 1  2024-04-21                 4.67                      4.89
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  4.89                        4.89                   4.76
# 1                  5.00                        5.00                   4.89
#
#   review_scores_value             license  calculated_host_listings_count  \
# 0                4.71  IT015146B4CCMWJAB7                              27
# 1                4.33                 NaN                               1
#
#   reviews_per_month
# 0              0.91
# 1              0.06
#
# [2 rows x 50 columns]

# %%
#description
data1["description"] =data1["description"].fillna("No description available")

#Neighborhood overview
data1["neighborhood_overview"] =data1["neighborhood_overview"].fillna("No description available")

#Host Location 
data1["host_location"] =data1["host_location"].fillna("Milan, Italy")

#host about 
data1["host_about"] =data1["host_about"].fillna("No description available")

#response time 
data1["host_response_time"] =data1["host_response_time"].fillna("N/A")

#response rate 
data1["host_response_rate"] =data1["host_response_rate"].fillna("N/A")

#acceptance rate 
data1["host_acceptance_rate"] =data1["host_acceptance_rate"].fillna("N/A")

#super host 
data1["host_is_superhost"] =data1["host_is_superhost"].fillna("f")

#host neighbourhood
data1["host_neighbourhood"] =data1["host_neighbourhood"].fillna("Not defined")

#availability  
data1["has_availability"] =data1["has_availability"].fillna("f")

#first review
data1["first_review"] =data1["first_review"].fillna("No date")

#last review
data1["last_review"] =data1["last_review"].fillna("No date")

#license
data1["license"] =data1["license"].fillna("Not included")

# %%
#beds
data1["beds"]= data1["beds"].fillna(1) 
data1.head(5)

#review score 
data1["review_scores_rating"]= data1["review_scores_rating"].fillna(0) 
data1.head(5)


#review score cleanliness
data1["review_scores_cleanliness"]= data1["review_scores_cleanliness"].fillna(0) 
data1.head(5)

#review score check-inn
data1["review_scores_checkin"]= data1["review_scores_checkin"].fillna(0) 
data1.head(5)

#review score communication
data1["review_scores_communication"]= data1["review_scores_communication"].fillna(0) 
data1.head(5)

#review score location
data1["review_scores_location"]= data1["review_scores_location"].fillna(0) 
data1.head(5)

#review score location
data1["review_scores_value"]= data1["review_scores_value"].fillna(0) 
data1.head(5)

#review scores per month 
data1["reviews_per_month"]= data1["reviews_per_month"].fillna(0) 
data1.head(5)
# Out:
#         scrape_id last_scraped       source  \
# 0  20250619031327   2025-06-19  city scrape
# 1  20250619031327   2025-06-19  city scrape
# 2  20250619031327   2025-06-19  city scrape
# 3  20250619031327   2025-06-19  city scrape
# 4  20250619031327   2025-06-19  city scrape
#
#                                               name  \
# 0         Milano Central Luxury - 3 BDR / 7 Guests
# 1           Porta Vigentina Triplex in City Center
# 2              Charming Nest, Central, Fiber-Optic
# 3                  Precious design bijoux downtonw
# 4  Vintage House in Milan Downtown with 5 bedrooms
#
#                                          description  \
# 0  A stylish and cozy apartment, beautifully furn...
# 1  The apartment is in a beautiful 18C building a...
# 2                           No description available
# 3                           No description available
# 4  The house is located in Porta Venezia district...
#
#                                neighborhood_overview  host_id  \
# 0  The Central Luxury apartment, is located just ...  2718914
# 1                           No description available   380378
# 2  The neighborhood is according to many the best...  1138330
# 3                           No description available   335105
# 4  Porta Venezia is a historic district, with som...  1225428
#
#                                     host_url    host_name  host_since  ...  \
# 0  https://www.airbnb.com/users/show/2718914       Nicola  2012-06-23  ...
# 1   https://www.airbnb.com/users/show/380378       Andrea  2011-02-07  ...
# 2  https://www.airbnb.com/users/show/1138330        Elena  2011-09-10  ...
# 3   https://www.airbnb.com/users/show/335105       Chiara  2011-01-04  ...
# 4  https://www.airbnb.com/users/show/1225428  Mariagrazia  2011-09-29  ...
#
#   last_review review_scores_rating review_scores_cleanliness  \
# 0  2025-05-20                 4.82                      4.90
# 1  2024-04-21                 4.67                      4.89
# 2  2025-06-09                 4.93                      4.95
# 3  2024-10-11                 4.65                      4.67
# 4  2025-05-18                 4.88                      4.92
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  4.89                        4.89                   4.76
# 1                  5.00                        5.00                   4.89
# 2                  4.96                        4.98                   4.90
# 3                  4.90                        4.92                   4.94
# 4                  4.91                        4.94                   4.93
#
#   review_scores_value             license  calculated_host_listings_count  \
# 0                4.71  IT015146B4CCMWJAB7                              27
# 1                4.33        Not included                               1
# 2                4.79  IT015146C2C5GZZERI                               1
# 3                4.59        Not included                               1
# 4                4.73  IT015146B4HLZC2L2S                               2
#
#   reviews_per_month
# 0              0.91
# 1              0.06
# 2              1.22
# 3              0.35
# 4              0.89
#
# [5 rows x 50 columns]

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
pd.set_option("display.max_rows", None)       # Todas las filas
valores_nulos
# Out:
# scrape_id                         0
# last_scraped                      0
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_url                          0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_neighbourhood                0
# host_listings_count               0
# host_total_listings_count         0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# bathrooms                         0
# beds                              0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# has_availability                  0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# calendar_last_scraped             0
# number_of_reviews                 0
# estimated_occupancy_l365d         0
# estimated_revenue_l365d           0
# first_review                      0
# last_review                       0
# review_scores_rating              0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# license                           0
# calculated_host_listings_count    0
# reviews_per_month                 0
# dtype: int64

# %%
#Convertir archivo filtrado a CSV
data1.to_csv("Valores_Nulos.csv")
